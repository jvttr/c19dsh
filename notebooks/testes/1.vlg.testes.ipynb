# %%
## set project path for python find source package
import sys
from pathlib import Path
from os import getcwd
from os.path import join, basename

current_dir = getcwd()
sys.path.append(str(Path(current_dir).parent.parent)) ## ../c19dsh <-- ../c19dsh/notebooks/testes

# %%
from src.data.get_dataset import get_casos_confirmados

# %%
import pandas as pd

# %%
cc = get_casos_confirmados()
cc
# Out:
#          IBGE_RES_PR  IBGE_ATEND_PR UF_RESIDENCIA SEXO  IDADE_ORIGINAL  \
# 0            4117503        4117503            PR    F              66
# 1            4108601        4108601            PR    M              71
# 2            4119905        4119905            PR    M              46
# 3            4115200        4115200            PR    F              71
# 4            4113700        4113700            PR    M              83
# ...              ...            ...           ...  ...             ...
# 2462820      4106902        4106902            PR    M              43
# 2462821      4106902        4106902            PR    M              15
# 2462822      4106902        4106902            PR    F              26
# 2462823      4106902        4106902            PR    F              26
# 2462824      4106902        4106902            PR    M              28
#
#         MUN_RESIDENCIA MUN_ATENDIMENTO  EXAME DATA_DIAGNOSTICO  \
# ...

# %%
cc.columns = [ col.lower() for col in cc.columns ]
